# %%
import numpy as np
import matplotlib.pyplot as plt
import background as bg

# %%
z = np.linspace(0,4,100)

# %%
plt.plot(z, bg.H_z(z))
plt.xlabel("z")
plt.ylabel("H(z)")
# Out:
# Text(0, 0.5, 'H(z)')

# %%
plt.plot(z, bg.comoving_distance(z))
plt.xlabel("z")
plt.ylabel("r(z)")
# Out:
# Text(0, 0.5, 'r(z)')
